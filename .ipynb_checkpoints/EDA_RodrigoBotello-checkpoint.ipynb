# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### EDA

# %%
data = pd.read_excel('Dataset.xlsx')
data.head(20)
# Out:
#     Year Geography              Type of work              Education level  \
# 0   1997    Canada  Both full- and part-time  Total, all education levels
# 1   1998    Canada  Both full- and part-time  Total, all education levels
# 2   1999    Canada  Both full- and part-time  Total, all education levels
# 3   2000    Canada  Both full- and part-time  Total, all education levels
# 4   2001    Canada  Both full- and part-time  Total, all education levels
# 5   2002    Canada  Both full- and part-time  Total, all education levels
# 6   2003    Canada  Both full- and part-time  Total, all education levels
# 7   2004    Canada  Both full- and part-time  Total, all education levels
# 8   2005    Canada  Both full- and part-time  Total, all education levels
# 9   2006    Canada  Both full- and part-time  Total, all education levels
# 10  2007    Canada  Both full- and part-time  Total, all education levels
# 11  2008    Canada  Both full- and part-time  Total, all education levels
# 12  2009    Canada  Both full- and part-time  Total, all education levels
# 13  2010    Canada  Both full- and part-time  Total, all education levels
# 14  2011    Canada  Both full- and part-time  Total, all education levels
# 15  2012    Canada  Both full- and part-time  Total, all education levels
# 16  2013    Canada  Both full- and part-time  Total, all education levels
# 17  2014    Canada  Both full- and part-time  Total, all education levels
# 18  2015    Canada  Both full- and part-time  Total, all education levels
# 19  2016    Canada  Both full- and part-time  Total, all education levels
#
#        Sex           Age group            Wages   Value
# 0     Male  15 years and over   Total employees  5954.5
# 1     Male  15 years and over   Total employees  6060.1
# 2     Male  15 years and over   Total employees  6203.8
# 3     Male  15 years and over   Total employees  6427.6
# 4     Male  15 years and over   Total employees  6520.2
# 5     Male  15 years and over   Total employees  6668.8
# 6     Male  15 years and over   Total employees  6763.8
# 7     Male  15 years and over   Total employees  6848.8
# 8     Male  15 years and over   Total employees  6929.0
# 9     Male  15 years and over   Total employees  7062.3
# 10    Male  15 years and over   Total employees  7147.6
# 11    Male  15 years and over   Total employees  7233.5
# 12    Male  15 years and over   Total employees  6964.4
# 13    Male  15 years and over   Total employees  7107.2
# 14    Male  15 years and over   Total employees  7302.5
# 15    Male  15 years and over   Total employees  7399.6
# 16    Male  15 years and over   Total employees  7511.6
# 17    Male  15 years and over   Total employees  7593.7
# 18    Male  15 years and over   Total employees  7680.1
# 19    Male  15 years and over   Total employees  7698.3

# %% [markdown]
# ### Data is Taken Equaly overtime

# %%
# Could they sample the same people? 
year_counts = dict(data['Year'].value_counts())
year_counts
# Out:
# {2016: 31680,
#  2015: 31680,
#  1998: 31680,
#  1999: 31680,
#  2000: 31680,
#  2001: 31680,
#  2002: 31680,
#  2003: 31680,
#  2004: 31680,
#  2005: 31680,
#  2006: 31680,
#  2007: 31680,
#  2008: 31680,
#  2009: 31680,
#  2010: 31680,
#  2011: 31680,
#  2012: 31680,
#  2013: 31680,
#  2014: 31680,
#  1997: 31680}

# %%
# Do more males/females live in certain areas? Huge no
for year in year_counts.keys(): 
    print(year)
    print(data.loc[data['Year'] == year]['Sex'].value_counts())
# Out:
# 2016
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2015
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 1998
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 1999
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2000
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2001
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2002
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2003
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2004
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2005
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2006
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2007
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2008
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2009
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2010
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2011
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2012
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2013
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 2014
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64
# 1997
#   Male      15840
#   Female    15840
# Name: Sex, dtype: int64

# %% [markdown]
# ### Same samples per city

# %%
# Maybe look at the distribution 
cities_counts = dict(data['Geography'].value_counts())
cities_counts
# Out:
# {'British Columbia': 57600,
#  'Canada': 57600,
#  'Manitoba': 57600,
#  'Saskatchewan': 57600,
#  'Nova Scotia': 57600,
#  'Quebec': 57600,
#  'Alberta': 57600,
#  'Prince Edward Island': 57600,
#  'Ontario': 57600,
#  'New Brunswick': 57600,
#  'Newfoundland and Labrador': 57600}

# %% [markdown]
# ### Data shows same number of men and same number of women per city

# %%
# Do more males/females live in certain areas? Huge no
for city in cities_counts.keys(): 
    print(city)
    print(data.loc[data['Geography'] == city]['Sex'].value_counts())
# Out:
# British Columbia
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Canada
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Manitoba
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Saskatchewan
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Nova Scotia
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Quebec
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Alberta
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Prince Edward Island
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Ontario
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# New Brunswick
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64
# Newfoundland and Labrador
#   Male      28800
#   Female    28800
# Name: Sex, dtype: int64

# %%
# Maybe look at the distribution 
workType_counts = dict(data['Type of work'].value_counts())
workType_counts
# Out:
# {'   Part-time ': 211200,
#  '   Full-time ': 211200,
#  'Both full- and part-time': 211200}

# %%
for workType in workType_counts.keys(): 
    print(data.loc[data['Type of work'] == workType]['Sex'].value_counts())

# %%
data['Sex'][0]
# Out:
# '  Male'

# %% [markdown]
# ### Male Describe Value

# %%
data[data['Sex'] == '  Male']['Value'].describe()
# Out:
# count    316800.000000
# mean        257.560230
# std         399.825258
# min           0.000000
# 25%          10.000000
# 50%          22.800000
# 75%         464.262500
# max        7698.300000
# Name: Value, dtype: float64

# %%
plt.figure()
plt.hist(data[data['Sex'] == '  Male']['Value'], bins = 25, range = (0, 1500))
plt.show()

# %% [markdown]
# ### Female Describe Value

# %%
data[data['Sex'] == '  Female']['Value'].describe()
# Out:
# count    316800.000000
# mean        212.983203
# std         320.262782
# min           0.000000
# 25%          11.320000
# 50%          22.000000
# 75%         374.400000
# max        7611.800000
# Name: Value, dtype: float64

# %%
plt.figure()
plt.hist(data[data['Sex'] == '  Female']['Value'], bins = 25, range = (0, 1500))
plt.show()

# %% [markdown]
# ### Comparison Between Sexes

# %%
male_value = data[data['Sex'] == '  Male']['Value']
female_value = data[data['Sex'] == '  Female']['Value']

plt.figure(figsize = (20, 10))
plt.hist(male_value, bins = 50, range = (0, 1500), alpha=0.6, label = 'Male')
plt.hist(female_value, bins = 50, range = (0, 1500),  alpha=0.6, color = 'pink', label = 'Female')
plt.legend(loc='upper right')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Comparison Between Sexes Value Range(100, 1500) for Vizualization Weekly Wage Rate Mean

# %%
male_value = data[data['Sex'] == '  Male']
female_value = data[data['Sex'] == '  Female']

male_weekly = male_value[male_value['Wages'] == 'Average weekly wage rate']
female_weekly = female_value[female_value['Wages'] == 'Average weekly wage rate']

male_value = male_value[male_value['Wages'] == 'Average weekly wage rate']['Value']
female_value = female_value[female_value['Wages'] == 'Average weekly wage rate']['Value']

plt.figure(figsize = (20, 10))
plt.hist(male_value, bins = 50, range = (50, 1500), alpha=0.6, label = 'Male')
plt.hist(female_value, bins = 50, range = (50, 1500),  alpha=0.6, color = 'pink', label = 'Female')
plt.legend(loc='upper right')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range 50 - 1500')
plt.show()

plt.figure(figsize = (20, 10))
plt.hist(male_value, bins = 50, range = (0, 50), alpha=0.6, label = 'Male')
plt.hist(female_value, bins = 50, range = (0, 50),  alpha=0.6, color = 'pink', label = 'Female')
plt.legend(loc='upper right')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range 0 - 50')
plt.show()

plt.figure(figsize = (20, 10))
plt.hist(male_value, bins = 50, range = (1500, 3000), alpha=0.6, label = 'Male')
plt.hist(female_value, bins = 50, range = (1500,3000),  alpha=0.6, color = 'pink', label = 'Female')
plt.legend(loc='upper right')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range 1500 -3000')
plt.show()

# %% [markdown]
# We notice a significant difference in the distribution for male vs female workers. It appears more women are lumped into the lower salaries and then the distribution decreases. in the case of male workers, we notice that there are two peaks as opposed to one decrease in the distribution. We excluded the outliars for the purpose of vizualization.

# %% [markdown]
# ### We can now break this distribution by city weekly

# %%
for city in cities_counts.keys():
    
    # Value Distribution by city
    male_cityValues = male_weekly.loc[males['Geography'] == city]['Value']
    female_cityValues = female_weekly.loc[females['Geography'] == city]['Value']
    
    #Print the Name of the city
    print(city, '\n'*2)
    
    # Plot
    plt.figure(figsize = (10, 5))
    plt.hist(male_cityValues, bins = 50, range = (50, 1500), alpha=0.6, label = 'Male')
    plt.hist(female_cityValues, bins = 50, range = (50, 1500),  alpha=0.6, color = 'pink', label = 'Female')
    plt.legend(loc='upper right')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Range 50 - 1500')
    plt.show()
    
    # Plot
    plt.figure(figsize = (10, 5))
    plt.hist(male_cityValues, bins = 50, range = (0, 50), alpha=0.6, label = 'Male')
    plt.hist(female_cityValues, bins = 50, range = (0, 50),  alpha=0.6, color = 'pink', label = 'Female')
    plt.legend(loc='upper right')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Range 0 - 50')
    plt.show()
    
    # Plot
    plt.figure(figsize = (10, 5))
    plt.hist(male_cityValues, bins = 50, range = (1500, 3000), alpha=0.6, label = 'Male')
    plt.hist(female_cityValues, bins = 50, range = (1500,3000),  alpha=0.6, color = 'pink', label = 'Female')
    plt.legend(loc='upper right')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Range 1500 -3000')
    plt.show()
    print('\n'*5)
# Out:
# British Columbia
# Canada
# Manitoba
# Saskatchewan
# Nova Scotia
# Quebec
# Alberta
# Prince Edward Island
# Ontario
# New Brunswick
# Newfoundland and Labrador

# %% [markdown]
# ### Same Vizualization but by year

# %%
for year in year_counts.keys():
    
    # Value Distribution by city
    male_cityValues = male_weekly.loc[males['Year'] == year]['Value']
    female_cityValues = female_weekly.loc[females['Year'] == year]['Value']
    
    #Print the Name of the city
    print(year, '\n'*2)
    
    # Plot
    plt.figure(figsize = (10, 5))
    plt.hist(male_value, bins = 50, range = (50, 1500), alpha=0.6, label = 'Male')
    plt.hist(female_value, bins = 50, range = (50, 1500),  alpha=0.6, color = 'pink', label = 'Female')
    plt.legend(loc='upper right')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Range 50 - 1500')
    plt.show()
    
    # Plot
    plt.figure(figsize = (10, 5))
    plt.hist(male_value, bins = 50, range = (0, 50), alpha=0.6, label = 'Male')
    plt.hist(female_value, bins = 50, range = (0, 50),  alpha=0.6, color = 'pink', label = 'Female')
    plt.legend(loc='upper right')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Range 0 - 50')
    plt.show()
    
    # Plot
    plt.figure(figsize = (10, 5))
    plt.hist(male_value, bins = 50, range = (1500, 3000), alpha=0.6, label = 'Male')
    plt.hist(female_value, bins = 50, range = (1500,3000),  alpha=0.6, color = 'pink', label = 'Female')
    plt.legend(loc='upper right')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Range 1500 -3000')
    plt.show()
    print('\n'*5)
# Out:
# 2016
# 2015
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1997

# %%
### Just go over all the columns lol 
columns = data.columns
# Out:
# Index(['Year', 'Geography', 'Type of work', 'Education level', 'Sex',
#        'Age group', 'Wages', 'Value'],
#       dtype='object')

# %%
for column in columns: 
    ColMales = dict(data[data['Sex'] == '  Male'][column].value_counts())
    ColFemales = dict(data[data['Sex'] == '  Female'][column].value_counts())
    
    # Get values from dictionary
    res_Males= []
    res_Females = []
    for key in ColMales.keys():
        res_Males.append(ColMales[key])
    for key in ColFemales.keys():
        res_Females.append(ColFemales[key])
        
    print(column, '\n')
    plt.figure(figsize = (20, 10))
    plt.bar(list(ColMales.keys()), res_Males,  alpha=0.6, label = 'Male')
    plt.bar(list(ColFemales.keys()), res_Females, alpha=0.6, color = 'pink', label = 'Female')
    plt.legend(loc='upper right')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Year
# Geography
# Type of work
# Education level
# Sex
# Age group
# Wages
# Value
